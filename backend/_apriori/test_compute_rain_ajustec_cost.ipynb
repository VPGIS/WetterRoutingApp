# %%
from utils_forecast import compute_rain_adjusted_cost

# %%
length = 1000
forecast = 0.1
rainresistence = 'medium'

compute_rain_adjusted_cost(length, forecast, rainresistence)
# Out:
# 7309.573444801933
